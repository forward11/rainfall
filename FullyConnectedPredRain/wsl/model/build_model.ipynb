# %%
import os
import json
from read_data import Reader
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import matplotlib.pyplot as plt
tf.random.set_seed(1)

def make_dataset():
    """
    To make tf.data.Dataset for training and test_x, test_y for testing and evaluation.
    :return: train_dataset, val_dataset, test_features, test_labels
    """
    reader = Reader()
    with open("E:\\rainfall\\FullyConnectedPredRain\\wsl\\model\\config.json", 'r') as json_file:
        config = json.load(json_file)

    features = config['features']
    train = reader.read_many('train', features)
    val = reader.read_many('val', features)
    test = reader.read_many('test', features)

    train_mean = train.mean(axis=0)['rainfall']
    train_std = train.std(axis=0)['rainfall']

    def normalization(dataframe):
        return (dataframe - train.mean(axis=0)) / train.std(axis=0)

    def dataframe_to_dataset(dataframe, shuffle=True, repeat=True, batch_size=16):
        dataframe = dataframe.copy()
        labels = dataframe.pop('rainfall')
        dataset = tf.data.Dataset.from_tensor_slices((dataframe, labels))
        if shuffle:
            dataset = dataset.shuffle(buffer_size=len(dataframe))
        dataset = dataset.batch(batch_size)
        if repeat:
            dataset = dataset.repeat()
        return dataset

    train, val, test = normalization(train), normalization(val), normalization(test)
    train_dataset = dataframe_to_dataset(train)
    val_dataset = dataframe_to_dataset(val, shuffle=False)
    test_labels = test.pop('rainfall')
    test_features = test
    return train_dataset, val_dataset, test_features, test_labels, train_mean, train_std


def dense_model_sequential_1():
    """
    To make a model in a sequential way (way 1).
    Performs exactly the same as the two methods below.
    :return: Model established
    """
    model = tf.keras.Sequential()
    model.add(layers.Dense(13, activation='sigmoid'))
    model.add(layers.Dense(50, activation='sigmoid'))
    model.add(layers.Dense(1))

    optimizer = tf.keras.optimizers.Adam(
        learning_rate=0.01
    )
    model.compile(loss='mse', optimizer=optimizer, metrics=['mae', 'mse'])

    return model


if __name__ == '__main__':
    epochs = 200
    size_train, size_val = 501, 174 #2091, 713
    batch_size = 16 #32
    train_ds, val_ds, test_x, test_y, train_mean, train_std = make_dataset()
    model = dense_model_sequential_1()
    callback = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', min_delta=0, patience=10, verbose=0,
        mode='auto', baseline=None, restore_best_weights=True
    )
    history = model.fit(train_ds, epochs=epochs, steps_per_epoch=size_train // batch_size,
                        validation_data=val_ds, validation_steps=size_val // batch_size,
                        callbacks=[callback])
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch
    print(model.summary())

    # if not os.path.exists('model'):
    #     os.makedirs('model')
    # model.save('model')

    # model = tf.keras.models.load_model('model')
    pred_y = model.predict(test_x)
    pred_y1=pred_y
    pred_y = pred_y * train_std + train_mean
    test_y = test_y * train_std + train_mean

    for index in range(len(pred_y)):
        if pred_y[index]<0:
            pred_y[index]=0

    # paint pred and real
    x = range(153)
    plt.plot(x, pred_y, label="pred", color="b")
    plt.plot(x, test_y, label="real", color="r")
    plt.legend()
    plt.show()
    plt.close()

    #paint loss and accuracy
    history_dict = history.history
    loss = history_dict['loss']
    val_loss = history_dict['val_loss']
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    plt.close()

    #result
    print((test_y.mean()-pred_y.mean())/pred_y.mean())
# Out:
# Epoch 1/200
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
#  1/31 [..............................] - ETA: 0s - loss: 14.0077 - mae: 2.1373 - mse: 14.0077WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0010s). Check your callbacks.
# 31/31 [==============================] - 0s 6ms/step - loss: 1.1261 - mae: 0.5544 - mse: 1.1261 - val_loss: 2.2242 - val_mae: 0.8256 - val_mse: 2.2242
# Epoch 2/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.8325 - mae: 0.4607 - mse: 0.8325 - val_loss: 2.0159 - val_mae: 0.7768 - val_mse: 2.0159
# Epoch 3/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7195 - mae: 0.4291 - mse: 0.7195 - val_loss: 1.8913 - val_mae: 0.8148 - val_mse: 1.8913
# Epoch 4/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5920 - mae: 0.3619 - mse: 0.5920 - val_loss: 1.8076 - val_mae: 0.9156 - val_mse: 1.8076
# Epoch 5/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6031 - mae: 0.4018 - mse: 0.6031 - val_loss: 1.8046 - val_mae: 0.8847 - val_mse: 1.8046
# Epoch 6/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6050 - mae: 0.3894 - mse: 0.6050 - val_loss: 1.7236 - val_mae: 0.7375 - val_mse: 1.7236
# Epoch 7/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5883 - mae: 0.3995 - mse: 0.5883 - val_loss: 1.6930 - val_mae: 0.7933 - val_mse: 1.6930
# Epoch 8/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4842 - mae: 0.3332 - mse: 0.4842 - val_loss: 1.7132 - val_mae: 0.8654 - val_mse: 1.7132
# Epoch 9/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4074 - mae: 0.3527 - mse: 0.4074 - val_loss: 1.6803 - val_mae: 0.8420 - val_mse: 1.6803
# Epoch 10/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5073 - mae: 0.3418 - mse: 0.5073 - val_loss: 1.7125 - val_mae: 0.8681 - val_mse: 1.7125
# Epoch 11/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6845 - mae: 0.3855 - mse: 0.6845 - val_loss: 1.7352 - val_mae: 0.8033 - val_mse: 1.7352
# Epoch 12/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.4551 - mae: 0.3486 - mse: 0.4551 - val_loss: 1.7321 - val_mae: 0.8553 - val_mse: 1.7321
# Epoch 13/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5196 - mae: 0.3740 - mse: 0.5196 - val_loss: 1.6958 - val_mae: 0.8147 - val_mse: 1.6958
# Epoch 14/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.5452 - mae: 0.3908 - mse: 0.5452 - val_loss: 1.8007 - val_mae: 1.0123 - val_mse: 1.8007
# Epoch 15/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4512 - mae: 0.3780 - mse: 0.4512 - val_loss: 1.6977 - val_mae: 0.7422 - val_mse: 1.6977
# Epoch 16/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4506 - mae: 0.3397 - mse: 0.4506 - val_loss: 1.7396 - val_mae: 0.9380 - val_mse: 1.7396
# Epoch 17/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5371 - mae: 0.3853 - mse: 0.5371 - val_loss: 1.6063 - val_mae: 0.7180 - val_mse: 1.6063
# Epoch 18/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2904 - mae: 0.3023 - mse: 0.2904 - val_loss: 1.6845 - val_mae: 0.6949 - val_mse: 1.6845
# Epoch 19/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6100 - mae: 0.4214 - mse: 0.6100 - val_loss: 1.6615 - val_mae: 0.6565 - val_mse: 1.6615
# Epoch 20/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3639 - mae: 0.3775 - mse: 0.3639 - val_loss: 1.5838 - val_mae: 0.6684 - val_mse: 1.5838
# Epoch 21/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4955 - mae: 0.3747 - mse: 0.4955 - val_loss: 1.6262 - val_mae: 0.7470 - val_mse: 1.6262
# Epoch 22/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3966 - mae: 0.3407 - mse: 0.3966 - val_loss: 1.5480 - val_mae: 0.7020 - val_mse: 1.5480
# Epoch 23/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3443 - mae: 0.3415 - mse: 0.3443 - val_loss: 1.5772 - val_mae: 0.6895 - val_mse: 1.5772
# Epoch 24/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3895 - mae: 0.3590 - mse: 0.3895 - val_loss: 1.6155 - val_mae: 0.7948 - val_mse: 1.6155
# Epoch 25/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4143 - mae: 0.3596 - mse: 0.4143 - val_loss: 1.5831 - val_mae: 0.7060 - val_mse: 1.5831
# Epoch 26/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3831 - mae: 0.3587 - mse: 0.3831 - val_loss: 1.6045 - val_mae: 0.7230 - val_mse: 1.6045
# Epoch 27/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3972 - mae: 0.3622 - mse: 0.3972 - val_loss: 1.6494 - val_mae: 0.7372 - val_mse: 1.6494
# Epoch 28/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3929 - mae: 0.3334 - mse: 0.3929 - val_loss: 1.5901 - val_mae: 0.7746 - val_mse: 1.5901
# Epoch 29/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3253 - mae: 0.3178 - mse: 0.3253 - val_loss: 1.6196 - val_mae: 0.7034 - val_mse: 1.6196
# Epoch 30/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4358 - mae: 0.3626 - mse: 0.4358 - val_loss: 1.6433 - val_mae: 0.8947 - val_mse: 1.6433
# Epoch 31/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3015 - mae: 0.3601 - mse: 0.3015 - val_loss: 1.5647 - val_mae: 0.8238 - val_mse: 1.5647
# Epoch 32/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3479 - mae: 0.3338 - mse: 0.3479 - val_loss: 1.5356 - val_mae: 0.7821 - val_mse: 1.5356
# Epoch 33/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3204 - mae: 0.3319 - mse: 0.3204 - val_loss: 1.5588 - val_mae: 0.6841 - val_mse: 1.5588
# Epoch 34/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3022 - mae: 0.3197 - mse: 0.3022 - val_loss: 1.5961 - val_mae: 0.6957 - val_mse: 1.5961
# Epoch 35/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.3456 - mae: 0.3460 - mse: 0.3456 - val_loss: 1.5469 - val_mae: 0.7881 - val_mse: 1.5469
# Epoch 36/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2949 - mae: 0.2970 - mse: 0.2949 - val_loss: 1.5777 - val_mae: 0.7436 - val_mse: 1.5777
# Epoch 37/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2861 - mae: 0.3098 - mse: 0.2861 - val_loss: 1.5433 - val_mae: 0.7308 - val_mse: 1.5433
# Epoch 38/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2564 - mae: 0.2961 - mse: 0.2564 - val_loss: 1.5666 - val_mae: 0.6912 - val_mse: 1.5666
# Epoch 39/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3120 - mae: 0.3121 - mse: 0.3120 - val_loss: 1.4952 - val_mae: 0.7717 - val_mse: 1.4952
# Epoch 40/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2671 - mae: 0.3029 - mse: 0.2671 - val_loss: 1.5791 - val_mae: 0.6746 - val_mse: 1.5791
# Epoch 41/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3682 - mae: 0.3565 - mse: 0.3682 - val_loss: 1.5360 - val_mae: 0.8031 - val_mse: 1.5360
# Epoch 42/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2411 - mae: 0.2898 - mse: 0.2411 - val_loss: 1.5528 - val_mae: 0.7142 - val_mse: 1.5528
# Epoch 43/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2828 - mae: 0.3049 - mse: 0.2828 - val_loss: 1.5243 - val_mae: 0.6916 - val_mse: 1.5243
# Epoch 44/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2437 - mae: 0.2926 - mse: 0.2437 - val_loss: 1.5284 - val_mae: 0.8003 - val_mse: 1.5284
# Epoch 45/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2178 - mae: 0.3030 - mse: 0.2178 - val_loss: 1.5664 - val_mae: 0.6766 - val_mse: 1.5664
# Epoch 46/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2841 - mae: 0.3301 - mse: 0.2841 - val_loss: 1.5373 - val_mae: 0.7480 - val_mse: 1.5373
# Epoch 47/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2660 - mae: 0.3069 - mse: 0.2660 - val_loss: 1.4700 - val_mae: 0.7337 - val_mse: 1.4700
# Epoch 48/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2718 - mae: 0.2919 - mse: 0.2718 - val_loss: 1.5046 - val_mae: 0.6889 - val_mse: 1.5046
# Epoch 49/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2017 - mae: 0.2578 - mse: 0.2017 - val_loss: 1.4851 - val_mae: 0.7041 - val_mse: 1.4851
# Epoch 50/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2518 - mae: 0.3058 - mse: 0.2518 - val_loss: 1.5095 - val_mae: 0.7411 - val_mse: 1.5095
# Epoch 51/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2494 - mae: 0.2980 - mse: 0.2494 - val_loss: 1.4815 - val_mae: 0.6953 - val_mse: 1.4815
# Epoch 52/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2240 - mae: 0.2647 - mse: 0.2240 - val_loss: 1.4987 - val_mae: 0.7570 - val_mse: 1.4987
# Epoch 53/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2405 - mae: 0.2866 - mse: 0.2405 - val_loss: 1.4755 - val_mae: 0.6813 - val_mse: 1.4755
# Epoch 54/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2391 - mae: 0.2867 - mse: 0.2391 - val_loss: 1.4933 - val_mae: 0.6823 - val_mse: 1.4933
# Epoch 55/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2101 - mae: 0.2814 - mse: 0.2101 - val_loss: 1.4493 - val_mae: 0.7320 - val_mse: 1.4493
# Epoch 56/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2660 - mae: 0.2999 - mse: 0.2660 - val_loss: 1.4822 - val_mae: 0.7076 - val_mse: 1.4822
# Epoch 57/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2135 - mae: 0.2734 - mse: 0.2135 - val_loss: 1.4571 - val_mae: 0.6989 - val_mse: 1.4571
# Epoch 58/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2172 - mae: 0.2779 - mse: 0.2172 - val_loss: 1.4865 - val_mae: 0.7458 - val_mse: 1.4865
# Epoch 59/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1804 - mae: 0.2604 - mse: 0.1804 - val_loss: 1.5004 - val_mae: 0.6738 - val_mse: 1.5004
# Epoch 60/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2194 - mae: 0.2809 - mse: 0.2194 - val_loss: 1.5260 - val_mae: 0.6510 - val_mse: 1.5260
# Epoch 61/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2334 - mae: 0.3044 - mse: 0.2334 - val_loss: 1.4192 - val_mae: 0.7170 - val_mse: 1.4192
# Epoch 62/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2456 - mae: 0.2951 - mse: 0.2456 - val_loss: 1.5169 - val_mae: 0.7975 - val_mse: 1.5169
# Epoch 63/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2525 - mae: 0.3047 - mse: 0.2525 - val_loss: 1.4144 - val_mae: 0.7829 - val_mse: 1.4144
# Epoch 64/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2186 - mae: 0.2858 - mse: 0.2186 - val_loss: 1.4539 - val_mae: 0.6574 - val_mse: 1.4539
# Epoch 65/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2296 - mae: 0.2867 - mse: 0.2296 - val_loss: 1.5324 - val_mae: 0.6598 - val_mse: 1.5324
# Epoch 66/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2106 - mae: 0.2890 - mse: 0.2106 - val_loss: 1.4350 - val_mae: 0.6482 - val_mse: 1.4350
# Epoch 67/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1732 - mae: 0.2450 - mse: 0.1732 - val_loss: 1.4188 - val_mae: 0.7065 - val_mse: 1.4188
# Epoch 68/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1881 - mae: 0.2566 - mse: 0.1881 - val_loss: 1.4701 - val_mae: 0.6493 - val_mse: 1.4701
# Epoch 69/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2109 - mae: 0.2547 - mse: 0.2109 - val_loss: 1.3818 - val_mae: 0.6871 - val_mse: 1.3818
# Epoch 70/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1887 - mae: 0.2567 - mse: 0.1887 - val_loss: 1.3952 - val_mae: 0.7325 - val_mse: 1.3952
# Epoch 71/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1588 - mae: 0.2511 - mse: 0.1588 - val_loss: 1.4243 - val_mae: 0.6765 - val_mse: 1.4243
# Epoch 72/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2229 - mae: 0.2867 - mse: 0.2229 - val_loss: 1.4223 - val_mae: 0.6922 - val_mse: 1.4223
# Epoch 73/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1923 - mae: 0.2548 - mse: 0.1923 - val_loss: 1.3712 - val_mae: 0.7119 - val_mse: 1.3712
# Epoch 74/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1808 - mae: 0.2540 - mse: 0.1808 - val_loss: 1.4127 - val_mae: 0.6769 - val_mse: 1.4127
# Epoch 75/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1613 - mae: 0.2490 - mse: 0.1613 - val_loss: 1.4374 - val_mae: 0.6518 - val_mse: 1.4374
# Epoch 76/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2177 - mae: 0.2570 - mse: 0.2177 - val_loss: 1.4119 - val_mae: 0.6762 - val_mse: 1.4119
# Epoch 77/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1583 - mae: 0.2305 - mse: 0.1583 - val_loss: 1.4226 - val_mae: 0.6574 - val_mse: 1.4226
# Epoch 78/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1417 - mae: 0.2273 - mse: 0.1417 - val_loss: 1.3987 - val_mae: 0.6923 - val_mse: 1.3987
# Epoch 79/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2191 - mae: 0.2734 - mse: 0.2191 - val_loss: 1.4035 - val_mae: 0.7226 - val_mse: 1.4035
# Epoch 80/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1507 - mae: 0.2518 - mse: 0.1507 - val_loss: 1.4609 - val_mae: 0.6413 - val_mse: 1.4609
# Epoch 81/200
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1701 - mae: 0.2187 - mse: 0.1701 - val_loss: 1.3950 - val_mae: 0.6901 - val_mse: 1.3950
# Epoch 82/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1796 - mae: 0.2523 - mse: 0.1796 - val_loss: 1.4231 - val_mae: 0.7106 - val_mse: 1.4231
# Epoch 83/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1534 - mae: 0.2284 - mse: 0.1534 - val_loss: 1.4328 - val_mae: 0.6456 - val_mse: 1.4328
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 13)                182
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                700
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 933
# Trainable params: 933
# Non-trainable params: 0
# _________________________________________________________________
# None
# -0.02668068648091759

# %%
from sklearn.metrics import r2_score
r_square = r2_score(y_true=test_y,y_pred=pred_y)
print("R-square is ",r_square)
# Out:
# R-square is  0.3615059712996177
